# %% [markdown]
# ## 💪🏻 **Configurando el músculo**
# ---
#
# Al contrario que en Spark, no poemos configurar el dimensionamiento de la máquina de Python a través de la UI.
#
# Lo haremos mediante el comando ```%%configure```:
# - Especificamos el nº de cores (4, 8, 16, 32, 64)
# - Fabric ajustará la memoria automáticamente en función de los cores especificados
#
# [Fuente](https://learn.microsoft.com/en-us/fabric/data-engineering/using-python-experience-on-notebook#session-configuration-magic-command)

# %%
# %%configure -f
# {
#     "vCores": 2
# }
